# %%
from eis_area_norm import process_eis_data, export_to_origin

# %%
result = process_eis_data()
# Out:
# -1.0
# Circuit string: R0-p(CPE1,R1)
# Fit: True
#
# Initial guesses:
#      R0 = 4.55e+01 [Ohm]
#   CPE1_0 = 6.77e-04 [Ohm^-1 sec^a]
#   CPE1_1 = 9.61e-01 []
#      R1 = 3.27e+03 [Ohm]
#
# Fit parameters:
#      R0 = 4.55e+01  (+/- 5.54e-01) [Ohm]
#   CPE1_0 = 6.77e-04  (+/- 6.68e-07) [Ohm^-1 sec^a]
#   CPE1_1 = 9.61e-01  (+/- 1.23e-03) []
#      R1 = 3.27e+03  (+/- 1.23e+01) [Ohm]
#
# -0.975
# Circuit string: R0-p(CPE1,R1)
# Fit: True
#
# Initial guesses:
#      R0 = 4.58e+01 [Ohm]
#   CPE1_0 = 6.78e-04 [Ohm^-1 sec^a]
#   CPE1_1 = 9.59e-01 []
#      R1 = 5.15e+03 [Ohm]
#
# Fit parameters:
#      R0 = 4.58e+01  (+/- 5.49e-01) [Ohm]
#   CPE1_0 = 6.78e-04  (+/- 5.63e-07) [Ohm^-1 sec^a]
#   CPE1_1 = 9.59e-01  (+/- 1.15e-03) []
#      R1 = 5.15e+03  (+/- 2.67e+01) [Ohm]
#
# -0.95
# Circuit string: R0-p(CPE1,R1)
# Fit: True
#
# Initial guesses:
#      R0 = 4.60e+01 [Ohm]
#   CPE1_0 = 6.86e-04 [Ohm^-1 sec^a]
#   CPE1_1 = 9.55e-01 []
#      R1 = 7.83e+03 [Ohm]
#
# Fit parameters:
# ...

# %%
export_to_origin(
    result["origin"],
    formula="(Q * (1/R0 + 1/R1)**(n - 1))**(1/n)*1e6",
    formula_name="C (mkF)",
    )
# Out:
# Connecting to Origin, please wait 5 seconds...
